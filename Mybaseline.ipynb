# %% [markdown]
# # !Link to challenge!
#
# # https://www.kaggle.com/t/b3ced76a60b94572a90740756f778fc8

# %% [markdown]
# ### Metric
#
# For binary classification with a true label y $\in \{0,1\}$ and a probability estimate p = $\operatorname{Pr}(y = 1)$, the log loss per sample is the negative log-likelihood of the classifier given the true label:
# $$
# L_{\log}(y, p) = -\log \operatorname{Pr}(y|p) = -(y \log (p) + (1 - y) \log (1 - p))$
# $$
#
# This extends to the multiclass case as follows. Let the true labels for a set of samples be encoded as a 1-of-K binary indicator matrix Y, i.e., $y_{i,k} = 1$ if sample i has label k taken from a set of K labels. Let P be a matrix of probability estimates, with $p_{i,k} = \operatorname{Pr}(t_{i,k} = 1)$. Then the log loss of the whole set is
#
# $$
# L_{\log}(Y, P) = -\log \operatorname{Pr}(Y|P) = - \frac{1}{N} \sum_{i=0}^{N-1} \sum_{k=0}^{K-1} y_{i,k} \log p_{i,k}
# $$

# %% [markdown]
# # Grading

# %% [markdown]
# #### Firstly, to get any mark, you must beat medium baseline score
#
# Your grade after challenge ends will be calculated as this:
# $$
# Grade = \frac{score - mid\_baseline\_score}{\#1\_score - mid\_baseline\_score} * 10
# $$
#
# where score will be taken from private part results.

# %% [markdown]
# ## About
#
# In this notebook we prepare a simple solution.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

# %% [markdown]
# ### Read training and test files

# %%
data = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
data.head()
# Out:
#          TrackP  TrackNDoFSubdetector2  BremDLLbeElectron  MuonLooseFlag  \
# 0  74791.156263                   15.0           0.232275            1.0
# 1   2738.489989                   15.0          -0.357748            0.0
# 2   2161.409908                   17.0        -999.000000            0.0
# 3  15277.730490                   20.0          -0.638984            0.0
# 4   7563.700195                   19.0          -0.638962            0.0
#
#    FlagSpd   SpdE  EcalDLLbeElectron     DLLmuon  RICHpFlagElectron  \
# 0      1.0    3.2          -2.505719    6.604153                1.0
# 1      1.0    3.2           1.864351    0.263651                1.0
# 2      0.0 -999.0        -999.000000 -999.000000                0.0
# 3      1.0    3.2          -2.533918   -8.724949                1.0
# 4      1.0    3.2          -2.087146   -7.060422                1.0
#
#    EcalDLLbeMuon        ...         TrackNDoF  RICHpFlagMuon  RICH_DLLbeKaon  \
# 0       1.929960        ...              28.0            1.0       -7.213300
# 1      -2.061959        ...              32.0            1.0       -0.324317
# 2    -999.000000        ...              27.0            0.0     -999.000000
# 3      -3.253981        ...              36.0            1.0      -35.202221
# 4      -0.995816        ...              33.0            1.0       25.084287
#
#    RICH_DLLbeElectron        HcalE  MuonFlag  FlagMuon        PrsE  \
# 0           -0.280200  5586.589846       1.0       1.0   10.422315
# 1            1.707283    -0.000007       0.0       1.0   43.334935
# 2         -999.000000  -999.000000       0.0       0.0 -999.000000
# 3          -14.742319  4482.803707       0.0       1.0    2.194175
# 4          -10.272412  5107.554680       0.0       1.0    0.000015
#
#    RICH_DLLbeMuon  RICH_DLLbeProton
# 0   -2.081143e-07        -24.824400
# 1    2.771583e+00         -0.648017
# 2   -9.990000e+02       -999.000000
# 3   -3.070819e+00        -29.291519
# 4   -5.373712e+00         23.653087
#
# [5 rows x 50 columns]

# %%
data[data.DLLmuon < -998].Label.head()
# Out:
# 2         Ghost
# 111       Ghost
# 125        Kaon
# 139      Proton
# 268    Electron
# Name: Label, dtype: object

# %%
test.head()
# Out:
#          TrackP  TrackNDoFSubdetector2  BremDLLbeElectron  MuonLooseFlag  \
# 0  55086.199233                   18.0          -0.438763            0.0
# 1   3393.820071                   17.0          -0.554341            0.0
# 2  18341.359361                   12.0          -0.554339            0.0
# 3  27486.710933                    7.0          -0.492411            1.0
# 4   6842.249996                   16.0           0.098706            0.0
#
#    FlagSpd  SpdE  EcalDLLbeElectron   DLLmuon  RICHpFlagElectron  \
# 0      1.0   3.2          -1.843821 -4.579244                1.0
# 1      1.0   0.0          -0.883237 -6.203035                1.0
# 2      1.0   0.0          -2.653786 -3.922639                1.0
# 3      1.0   3.2        -999.000000  2.034453                1.0
# 4      1.0   3.2           2.644499 -1.471364                1.0
#
#    EcalDLLbeMuon ...  RICHpFlagMuon  RICH_DLLbeKaon  RICH_DLLbeElectron  \
# 0      -1.732886 ...            1.0       18.674086           -1.355015
# 1      -0.097206 ...            1.0       16.536804          -17.601196
# 2       0.936484 ...            1.0       -1.306109           -4.536409
# 3    -999.000000 ...            1.0       -4.222793            3.149207
# 4      -2.909470 ...            1.0       -3.425113           23.147387
#
#           HcalE  MuonFlag  FlagMuon       PrsE  RICH_DLLbeMuon  \
# 0  24510.990244       0.0       1.0   9.325265       -0.250015
# 1    778.675303       0.0       1.0  -0.000006       -6.646096
# 2   7915.212420       0.0       1.0   1.371346       -2.132609
# 3   -999.000000       1.0       1.0  61.985428        0.946207
# 4     -0.000013       0.0       1.0   2.468453        2.614987
#
#    RICH_DLLbeProton  ID
# 0         35.408585   0
# 1         14.011904   1
# 2         -5.617409   2
# 3         -8.657193   3
# 4         -5.713513   4
#
# [5 rows x 50 columns]

# %%
data.shape
# Out:
# (1200000, 50)

# %%
ss = data.isin([-999.0])
ss
# Out:
#          TrackP  TrackNDoFSubdetector2  BremDLLbeElectron  MuonLooseFlag  \
# 0         False                  False              False          False
# 1         False                  False              False          False
# 2         False                  False               True          False
# 3         False                  False              False          False
# 4         False                  False              False          False
# 5         False                  False              False          False
# 6         False                  False              False          False
# 7         False                  False              False          False
# 8         False                  False               True          False
# 9         False                  False              False          False
# 10        False                  False              False          False
# 11        False                  False              False          False
# 12        False                  False              False          False
# 13        False                  False              False          False
# 14        False                  False               True          False
# 15        False                  False              False          False
# 16        False                  False              False          False
# 17        False                  False               True          False
# 18        False                  False              False          False
# 19        False                  False              False          False
# 20        False                  False              False          False
# 21        False                  False              False          False
# 22        False                  False              False          False
# 23        False                  False               True          False
# 24        False                  False              False          False
# 25        False                  False              False          False
# 26        False                  False              False          False
# 27        False                  False              False          False
# 28        False                  False              False          False
# 29        False                  False              False          False
# ...         ...                    ...                ...            ...
# 1199970   False                  False              False          False
# 1199971   False                  False               True          False
# 1199972   False                  False               True          False
# 1199973   False                  False               True          False
# 1199974   False                  False              False          False
# 1199975   False                  False              False          False
# 1199976   False                  False              False          False
# 1199977   False                  False              False          False
# 1199978   False                  False              False          False
# 1199979   False                  False              False          False
# 1199980   False                  False              False          False
# 1199981   False                  False              False          False
# 1199982   False                  False              False          False
# 1199983   False                  False              False          False
# 1199984   False                  False              False          False
# 1199985   False                  False              False          False
# 1199986   False                  False               True          False
# 1199987   False                  False              False          False
# 1199988   False                  False              False          False
# 1199989   False                  False              False          False
# 1199990   False                  False              False          False
# 1199991   False                  False               True          False
# 1199992   False                  False               True          False
# 1199993   False                  False               True          False
# 1199994   False                  False              False          False
# 1199995   False                  False              False          False
# 1199996   False                  False               True          False
# 1199997   False                  False               True          False
# 1199998   False                  False              False          False
# 1199999   False                  False              False          False
#
#          FlagSpd   SpdE  EcalDLLbeElectron  DLLmuon  RICHpFlagElectron  \
# 0          False  False              False    False              False
# 1          False  False              False    False              False
# 2          False   True               True     True              False
# 3          False  False              False    False              False
# 4          False  False              False    False              False
# 5          False  False              False    False              False
# 6          False  False              False    False              False
# 7          False  False              False    False              False
# 8          False  False               True    False              False
# 9          False  False              False    False              False
# 10         False  False               True    False              False
# 11         False  False              False    False              False
# 12         False  False              False    False              False
# 13         False  False              False    False              False
# 14         False  False              False    False              False
# 15         False  False              False    False              False
# 16         False  False               True    False              False
# 17         False  False              False    False              False
# 18         False  False              False    False              False
# 19         False  False              False    False              False
# 20         False  False              False    False              False
# 21         False  False              False    False              False
# 22         False  False              False    False              False
# 23         False  False              False    False              False
# 24         False  False              False    False              False
# 25         False  False              False    False              False
# 26         False  False              False    False              False
# 27         False  False              False    False              False
# 28         False  False              False    False              False
# 29         False  False              False    False              False
# ...          ...    ...                ...      ...                ...
# 1199970    False  False              False    False              False
# 1199971    False  False              False    False              False
# 1199972    False  False              False    False              False
# 1199973    False  False              False    False              False
# 1199974    False  False              False    False              False
# 1199975    False  False              False    False              False
# 1199976    False  False              False    False              False
# 1199977    False  False              False    False              False
# 1199978    False  False              False    False              False
# 1199979    False  False              False    False              False
# 1199980    False   True               True    False              False
# 1199981    False  False              False    False              False
# 1199982    False  False              False    False              False
# 1199983    False  False              False    False              False
# 1199984    False  False              False    False              False
# 1199985    False  False              False    False              False
# 1199986    False   True               True    False              False
# 1199987    False  False              False    False              False
# 1199988    False  False              False    False              False
# 1199989    False   True               True    False              False
# 1199990    False  False              False    False              False
# 1199991    False  False              False    False              False
# 1199992    False  False              False    False              False
# 1199993    False  False              False    False              False
# 1199994    False  False              False    False              False
# 1199995    False  False              False    False              False
# 1199996    False  False              False    False              False
# 1199997    False   True               True    False              False
# 1199998    False  False              False    False              False
# 1199999    False  False              False    False              False
#
#          EcalDLLbeMuon        ...         TrackNDoF  RICHpFlagMuon  \
# 0                False        ...             False          False
# 1                False        ...             False          False
# 2                 True        ...             False          False
# 3                False        ...             False          False
# 4                False        ...             False          False
# 5                False        ...             False          False
# 6                False        ...             False          False
# 7                False        ...             False          False
# 8                 True        ...             False          False
# 9                False        ...             False          False
# 10                True        ...             False          False
# 11               False        ...             False          False
# 12               False        ...             False          False
# 13               False        ...             False          False
# 14               False        ...             False          False
# 15               False        ...             False          False
# 16                True        ...             False          False
# 17               False        ...             False          False
# 18               False        ...             False          False
# 19               False        ...             False          False
# 20               False        ...             False          False
# 21               False        ...             False          False
# 22               False        ...             False          False
# 23               False        ...             False          False
# 24               False        ...             False          False
# 25               False        ...             False          False
# 26               False        ...             False          False
# 27               False        ...             False          False
# 28               False        ...             False          False
# 29               False        ...             False          False
# ...                ...        ...               ...            ...
# 1199970          False        ...             False          False
# 1199971          False        ...             False          False
# 1199972          False        ...             False          False
# 1199973          False        ...             False          False
# 1199974          False        ...             False          False
# 1199975          False        ...             False          False
# 1199976          False        ...             False          False
# 1199977          False        ...             False          False
# 1199978          False        ...             False          False
# 1199979          False        ...             False          False
# 1199980           True        ...             False          False
# 1199981          False        ...             False          False
# 1199982          False        ...             False          False
# 1199983          False        ...             False          False
# 1199984          False        ...             False          False
# 1199985          False        ...             False          False
# 1199986           True        ...             False          False
# 1199987          False        ...             False          False
# 1199988          False        ...             False          False
# 1199989           True        ...             False          False
# 1199990          False        ...             False          False
# 1199991          False        ...             False          False
# 1199992          False        ...             False          False
# 1199993          False        ...             False          False
# 1199994          False        ...             False          False
# 1199995          False        ...             False          False
# 1199996          False        ...             False          False
# 1199997           True        ...             False          False
# 1199998          False        ...             False          False
# 1199999          False        ...             False          False
#
#          RICH_DLLbeKaon  RICH_DLLbeElectron  HcalE  MuonFlag  FlagMuon   PrsE  \
# 0                 False               False  False     False     False  False
# 1                 False               False  False     False     False  False
# 2                  True                True   True     False     False   True
# 3                 False               False  False     False     False  False
# 4                 False               False  False     False     False  False
# 5                 False               False  False     False     False  False
# 6                 False               False  False     False     False  False
# 7                 False               False  False     False     False  False
# 8                 False               False   True     False     False  False
# 9                 False               False  False     False     False  False
# 10                False               False   True     False     False  False
# 11                False               False  False     False     False  False
# 12                False               False  False     False     False  False
# 13                False               False  False     False     False  False
# 14                False               False  False     False     False  False
# 15                False               False  False     False     False  False
# 16                False               False   True     False     False  False
# 17                False               False  False     False     False  False
# 18                False               False  False     False     False  False
# 19                False               False  False     False     False  False
# 20                False               False  False     False     False  False
# 21                False               False  False     False     False  False
# 22                False               False  False     False     False  False
# 23                False               False  False     False     False  False
# 24                False               False  False     False     False  False
# 25                False               False   True     False     False  False
# 26                False               False  False     False     False  False
# 27                False               False  False     False     False  False
# 28                False               False  False     False     False  False
# 29                False               False  False     False     False  False
# ...                 ...                 ...    ...       ...       ...    ...
# 1199970           False               False  False     False     False  False
# 1199971           False               False  False     False     False  False
# 1199972           False               False  False     False     False  False
# 1199973           False               False  False     False     False  False
# 1199974           False               False  False     False     False  False
# 1199975           False               False  False     False     False  False
# 1199976           False               False  False     False     False  False
# 1199977           False               False  False     False     False  False
# 1199978           False               False  False     False     False  False
# 1199979           False               False  False     False     False  False
# 1199980           False               False   True     False     False   True
# 1199981           False               False  False     False     False  False
# 1199982            True                True  False     False     False  False
# 1199983           False               False  False     False     False  False
# 1199984           False               False  False     False     False  False
# 1199985           False               False  False     False     False  False
# 1199986           False               False   True     False     False   True
# 1199987           False               False  False     False     False  False
# 1199988           False               False  False     False     False  False
# 1199989           False               False   True     False     False   True
# 1199990           False               False  False     False     False  False
# 1199991           False               False  False     False     False  False
# 1199992           False               False  False     False     False  False
# 1199993           False               False  False     False     False  False
# 1199994           False               False  False     False     False  False
# 1199995           False               False   True     False     False  False
# 1199996            True                True  False     False     False  False
# 1199997           False               False   True     False     False   True
# 1199998           False               False  False     False     False  False
# 1199999           False               False  False     False     False  False
#
#          RICH_DLLbeMuon  RICH_DLLbeProton
# 0                 False             False
# 1                 False             False
# 2                  True              True
# 3                 False             False
# 4                 False             False
# 5                 False             False
# 6                 False             False
# 7                 False             False
# 8                 False             False
# 9                 False             False
# 10                False             False
# 11                False             False
# 12                False             False
# 13                False             False
# 14                False             False
# 15                False             False
# 16                False             False
# 17                False             False
# 18                False             False
# 19                False             False
# 20                False             False
# 21                False             False
# 22                False             False
# 23                False             False
# 24                False             False
# 25                False             False
# 26                False             False
# 27                False             False
# 28                False             False
# 29                False             False
# ...                 ...               ...
# 1199970           False             False
# 1199971           False             False
# 1199972           False             False
# 1199973           False             False
# 1199974           False             False
# 1199975           False             False
# 1199976           False             False
# 1199977           False             False
# 1199978           False             False
# 1199979           False             False
# 1199980           False             False
# 1199981           False             False
# 1199982            True              True
# 1199983           False             False
# 1199984           False             False
# 1199985           False             False
# 1199986           False             False
# 1199987           False             False
# 1199988           False             False
# 1199989           False             False
# 1199990           False             False
# 1199991           False             False
# 1199992           False             False
# 1199993           False             False
# 1199994           False             False
# 1199995           False             False
# 1199996            True              True
# 1199997           False             False
# 1199998           False             False
# 1199999           False             False
#
# [1200000 rows x 50 columns]

# %%
ss = data.isin([-999.0])
s = ss.apply(pd.Series.value_counts, axis=1)
s[True].value_counts()
# Out:
# 2.0     550902
# 14.0    119868
# 3.0     114948
# 4.0      63425
# 5.0      56974
# 15.0     34372
# 8.0      32122
# 11.0     22141
# 1.0      15380
# 24.0     13308
# 12.0     12034
# 7.0      10754
# 6.0       8781
# 13.0      7101
# 9.0       6186
# 10.0      4620
# 17.0      1003
# 19.0       480
# 16.0        89
# 23.0        83
# 18.0         3
# Name: True, dtype: int64

# %%
s[True].value_counts(dropna = False)
# Out:
#  2.0     550902
# NaN      125426
#  14.0    119868
#  3.0     114948
#  4.0      63425
#  5.0      56974
#  15.0     34372
#  8.0      32122
#  11.0     22141
#  1.0      15380
#  24.0     13308
#  12.0     12034
#  7.0      10754
#  6.0       8781
#  13.0      7101
#  9.0       6186
#  10.0      4620
#  17.0      1003
#  19.0       480
#  16.0        89
#  23.0        83
#  18.0         3
# Name: True, dtype: int64

# %%
data2 = data[(s[True] < 1)  | (s[True].isna())]

# %%
data2.shape
# Out:
# (125426, 50)

# %%
for i in range(50):
    print(ss.iloc[:, i].value_counts())
# Out:
# False    1200000
# Name: TrackP, dtype: int64
# False    1200000
# Name: TrackNDoFSubdetector2, dtype: int64
# False    950439
# True     249561
# Name: BremDLLbeElectron, dtype: int64
# False    1200000
# Name: MuonLooseFlag, dtype: int64
# False    1200000
# Name: FlagSpd, dtype: int64
# False    1023833
# True      176167
# Name: SpdE, dtype: int64
# False    981143
# True     218857
# Name: EcalDLLbeElectron, dtype: int64
# False    1186609
# True       13391
# Name: DLLmuon, dtype: int64
# False    1200000
# Name: RICHpFlagElectron, dtype: int64
# False    981143
# True     218857
# Name: EcalDLLbeMuon, dtype: int64
# False    1200000
# Name: TrackQualitySubdetector2, dtype: int64
# False    1200000
# Name: FlagPrs, dtype: int64
# False    1186609
# True       13391
# Name: DLLelectron, dtype: int64
# False    1186609
# True       13391
# Name: DLLkaon, dtype: int64
# False    981143
# True     218857
# Name: EcalE, dtype: int64
# False    1200000
# Name: TrackQualityPerNDoF, dtype: int64
# False    1186609
# True       13391
# Name: DLLproton, dtype: int64
# False    1021505
# True      178495
# Name: PrsDLLbeElectron, dtype: int64
# False    1200000
# Name: FlagRICH1, dtype: int64
# True     971253
# False    228747
# Name: MuonLLbeBCK, dtype: int64
# False    1200000
# Name: FlagHcal, dtype: int64
# False    840807
# True     359193
# Name: EcalShowerLongitudinalParameter, dtype: int64
# False    980527
# True     219473
# Name: Calo2dFitQuality, dtype: int64
# False    1200000
# Name: TrackPt, dtype: int64
# False    1200000
# Name: TrackDistanceToZ, dtype: int64
# False    1200000
# Name: RICHpFlagPion, dtype: int64
# False    918014
# True     281986
# Name: HcalDLLbeElectron, dtype: int64
# False    840807
# True     359193
# Name: Calo3dFitQuality, dtype: int64
# False    1200000
# Name: FlagEcal, dtype: int64
# True     971253
# False    228747
# Name: MuonLLbeMuon, dtype: int64
# False    1200000
# Name: TrackNDoFSubdetector1, dtype: int64
# False    1200000
# Name: RICHpFlagProton, dtype: int64
# False    1200000
# Name: RICHpFlagKaon, dtype: int64
# False    1200000
# Name: GhostProbability, dtype: int64
# False    1200000
# Name: TrackQualitySubdetector1, dtype: int64
# False    1200000
# Name: Label, dtype: int64
# False    1141762
# True       58238
# Name: RICH_DLLbeBCK, dtype: int64
# False    1200000
# Name: FlagRICH2, dtype: int64
# False    1200000
# Name: FlagBrem, dtype: int64
# False    918014
# True     281986
# Name: HcalDLLbeMuon, dtype: int64
# False    1200000
# Name: TrackNDoF, dtype: int64
# False    1200000
# Name: RICHpFlagMuon, dtype: int64
# False    1141762
# True       58238
# Name: RICH_DLLbeKaon, dtype: int64
# False    1141762
# True       58238
# Name: RICH_DLLbeElectron, dtype: int64
# False    918014
# True     281986
# Name: HcalE, dtype: int64
# False    1200000
# Name: MuonFlag, dtype: int64
# False    1200000
# Name: FlagMuon, dtype: int64
# False    1021505
# True      178495
# Name: PrsE, dtype: int64
# False    1141762
# True       58238
# Name: RICH_DLLbeMuon, dtype: int64
# False    1141762
# True       58238
# Name: RICH_DLLbeProton, dtype: int64

# %%
s[-999].value_counts()
# Out:
# 2.0     4578
# 14.0    1057
# 3.0      904
# 4.0      552
# 5.0      490
# 8.0      275
# 15.0     271
# 11.0     184
# 1.0      135
# 24.0     121
# 12.0     101
# 7.0       88
# 6.0       70
# 9.0       55
# 13.0      54
# 10.0      44
# 17.0       6
# 16.0       2
# 19.0       1
# Name: -999.0, dtype: int64

# %%
data.loc[:10]
# Out:
#           TrackP  TrackNDoFSubdetector2  BremDLLbeElectron  MuonLooseFlag  \
# 0   74791.156263                   15.0           0.232275            1.0
# 1    2738.489989                   15.0          -0.357748            0.0
# 2    2161.409908                   17.0        -999.000000            0.0
# 3   15277.730490                   20.0          -0.638984            0.0
# 4    7563.700195                   19.0          -0.638962            0.0
# 5   62641.621090                   17.0           0.976355            0.0
# 6   18872.810570                   14.0           2.345886            0.0
# 7    1993.550048                    3.0           0.170659            0.0
# 8   90635.296871                    8.0        -999.000000            0.0
# 9   11633.669941                   16.0           0.976349            0.0
# 10   3432.929934                    8.0          -0.542416            0.0
#
#     FlagSpd   SpdE  EcalDLLbeElectron     DLLmuon  RICHpFlagElectron  \
# 0       1.0    3.2          -2.505719    6.604153                1.0
# 1       1.0    3.2           1.864351    0.263651                1.0
# 2       0.0 -999.0        -999.000000 -999.000000                0.0
# 3       1.0    3.2          -2.533918   -8.724949                1.0
# 4       1.0    3.2          -2.087146   -7.060422                1.0
# 5       1.0    3.2          -2.649216   -3.767491                1.0
# 6       1.0    3.2          -3.027858   -5.173245                1.0
# 7       1.0    0.0           1.864349    0.101000                1.0
# 8       1.0    3.2        -999.000000    0.000002                1.0
# 9       1.0    0.0          -2.479154   -0.631769                1.0
# 10      1.0    0.0        -999.000000    6.701406                1.0
#
#     EcalDLLbeMuon        ...         TrackNDoF  RICHpFlagMuon  RICH_DLLbeKaon  \
# 0        1.929960        ...              28.0            1.0       -7.213300
# 1       -2.061959        ...              32.0            1.0       -0.324317
# 2     -999.000000        ...              27.0            0.0     -999.000000
# 3       -3.253981        ...              36.0            1.0      -35.202221
# 4       -0.995816        ...              33.0            1.0       25.084287
# 5        1.282086        ...              40.0            1.0       29.475203
# 6        0.750181        ...              26.0            1.0       26.711504
# 7        0.382705        ...              13.0            0.0        0.000006
# 8     -999.000000        ...              22.0            1.0       -1.552902
# 9        0.449661        ...              28.0            1.0        9.489098
# 10    -999.000000        ...              27.0            1.0        5.715908
#
#     RICH_DLLbeElectron         HcalE  MuonFlag  FlagMuon        PrsE  \
# 0            -0.280200   5586.589846       1.0       1.0   10.422315
# 1             1.707283     -0.000007       0.0       1.0   43.334935
# 2          -999.000000   -999.000000       0.0       0.0 -999.000000
# 3           -14.742319   4482.803707       0.0       1.0    2.194175
# 1199999       0.0       1.0    2.468456   -2.510606e+00     -1.909211e+01
#
# [950439 rows x 50 columns]

# %%
(data.BremDLLbeElectron == -999).count()
# Out:
# 1200000

# %%
np.max(data['BremDLLbeElectron'].value_counts())
# Out:
# 249561

# %%
data2 = data.groupby('BremDLLbeElectron').count()

# %%
data2.shape
# Out:
# (950150, 49)

# %% [markdown]
# ### Look at the labels set

# %%
set(data.Label)
# Out:
# {'Electron', 'Ghost', 'Kaon', 'Muon', 'Pion', 'Proton'}

# %% [markdown]
# ### Define training features
#
# Exclude `Label` from the features set

# %%
features = list(set(data.columns) - {'Label'})
features
# Out:
# ['TrackNDoFSubdetector1',
#  'RICH_DLLbeProton',
#  'TrackNDoFSubdetector2',
#  'DLLmuon',
#  'FlagRICH1',
#  'FlagSpd',
#  'FlagRICH2',
#  'DLLelectron',
#  'GhostProbability',
#  'TrackP',
#  'RICHpFlagProton',
#  'TrackDistanceToZ',
#  'HcalDLLbeElectron',
#  'TrackQualityPerNDoF',
#  'FlagPrs',
#  'TrackNDoF',
#  'MuonLLbeMuon',
#  'FlagBrem',
#  'EcalDLLbeElectron',
#  'EcalDLLbeMuon',
#  'FlagHcal',
#  'EcalShowerLongitudinalParameter',
#  'RICHpFlagKaon',
#  'MuonLLbeBCK',
#  'Calo3dFitQuality',
#  'FlagMuon',
#  'BremDLLbeElectron',
#  'MuonFlag',
#  'MuonLooseFlag',
#  'DLLproton',
#  'RICH_DLLbeMuon',
#  'RICH_DLLbeKaon',
#  'PrsDLLbeElectron',
#  'DLLkaon',
#  'EcalE',
#  'FlagEcal',
#  'RICHpFlagElectron',
#  'Calo2dFitQuality',
#  'HcalE',
#  'TrackQualitySubdetector1',
#  'PrsE',
#  'HcalDLLbeMuon',
#  'RICH_DLLbeElectron',
#  'RICH_DLLbeBCK',
#  'TrackPt',
#  'RICHpFlagMuon',
#  'TrackQualitySubdetector2',
#  'RICHpFlagPion',
#  'SpdE']

# %% [markdown]
# ### Divide training data into 2 parts

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier

# %%
training_data, validation_data = train_test_split(data, random_state=11, train_size=0.1, test_size = 0.9)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(training_data[features])
X_val = scaler.fit_transform(validation_data[features])

# %%
len(training_data), len(validation_data)
# Out:
# (120000, 1080000)

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, training_data.Label)
proba = tree.predict_proba(X_val)
log_loss(validation_data.Label, proba)
# Out:
# 12.831347312800409

# %%
clf = ExtraTreesClassifier(n_estimators=500, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=5)
clf.fit(X_train, training_data.Label)
proba = clf.predict_proba(X_val)
log_loss(validation_data.Label, proba)
# Out:
# 0.68939210045137778

# %%
data2 = data[(s[True] < 16)  | (s[True].isna())]
data3 = data[s[True] > 15]
print(data2.shape)
print(data3.shape)
# Out:
# (1185034, 50)
# (14966, 50)

# %%
training_data, aaa = train_test_split(data2, random_state=11, train_size=0.2, test_size = 0.0)
bbb, validation_data = train_test_split(data, random_state=250, train_size=0.00, test_size = 0.2)

X_train = scaler.fit_transform(training_data[features])
X_val = scaler.fit_transform(validation_data[features])

# %%
print(X_train.shape)
print(X_val.shape)
# Out:
# (237006, 49)
# (240000, 49)

# %%
X_train = scaler.fit_transform(data[features])
X_train.shape
# Out:
# (1200000, 49)

# %%
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=5)
clf.fit(X_train, training_data.Label)
proba = clf.predict_proba(X_val)
log_loss(validation_data.Label, proba)
# Out:
# 1.0413836076932936

# %%
clf = KNeighborsClassifier(n_neighbors=5, leaf_size=30,
                           p=2, metric_params=None, n_jobs=4)
clf.fit(X_train, training_data.Label)
proba = clf.predict_proba(X_val)
log_loss(validation_data.Label, proba)

# %%
param_grid ={'min_samples_leaf': [1, 10]}
gscv = GridSearchCV(clf, param_grid, scoring='neg_log_loss', cv=3)
#gscv = GridSearchCV(clf, param_grid, scoring='neg_log_loss', cv=3, n_jobs=-1, verbose=1)
gscv.fit(X_train, training_data.Label)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=6, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': [1, 10]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score=True, scoring='neg_log_loss',
#        verbose=0)

# %%
gscv.best_params_
# Out:
# {'n_estimators': 2}

# %%
from sklearn.ensemble import GradientBoostingClassifier as XGBClassifier

# %%
clf2 = XGBClassifier(learning_rate= 0.3, n_estimators=50, subsample=1.0,
                            min_samples_split=2, min_samples_leaf = 3, 
                           min_weight_fraction_leaf=0.0, max_depth=3,
                           min_impurity_split=None, init=None, random_state=None,
                           max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False)

clf2.fit(X_train, training_data.Label)
proba = clf2.predict_proba(X_val)
print(log_loss(validation_data.Label, proba))

# %%
from sklearn.model_selection import GridSearchCV
param_grid ={'max_depth': np.linspace(1,9,5)}
gscv = GridSearchCV(clf2, param_grid, scoring='neg_log_loss', cv=3)
#gscv = GridSearchCV(clf, param_grid, scoring='neg_log_loss', cv=3, n_jobs=-1, verbose=1)
gscv.fit(X_train, training_data.Label)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-590e9278688a> in <module>()
#       3 gscv = GridSearchCV(clf2, param_grid, scoring='neg_log_loss', cv=3)
#       4 #gscv = GridSearchCV(clf, param_grid, scoring='neg_log_loss', cv=3, n_jobs=-1, verbose=1)
# ----> 5 gscv.fit(X_train, training_data.Label)
#
# /anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups, **fit_params)
#     636                                   error_score=self.error_score)
#     637           for parameters, (train, test) in product(candidate_params,
# --> 638                                                    cv.split(X, y, groups)))
#     639
#     640         # if one choose to see train score, "out" will contain train score info
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     435             estimator.fit(X_train, **fit_params)
#     436         else:
# --> 437             estimator.fit(X_train, y_train, **fit_params)
#     438
#     439     except Exception as e:
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# /anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
gscv.fit(X_train, training_data.Label)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-02c14baedc3a> in <module>()
# ----> 1 gscv.fit(X_train, training_data.Label)
#
# /anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups, **fit_params)
#     636                                   error_score=self.error_score)
#     637           for parameters, (train, test) in product(candidate_params,
# --> 638                                                    cv.split(X, y, groups)))
#     639
#     640         # if one choose to see train score, "out" will contain train score info
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     435             estimator.fit(X_train, **fit_params)
#     436         else:
# --> 437             estimator.fit(X_train, y_train, **fit_params)
#     438
#     439     except Exception as e:
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# /anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# /anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
gscv.best_params_
# Out:
# 0.74428425925925923

# %% [markdown]
# ### Simple logistic regression forest from `sklearn` training
#
# train multiclassification model

# %%
from xgboost import XGBClassifier,XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-46-fad4e8f41c98> in <module>()
# ----> 1 from xgboost import XGBClassifier,XGBRegressor
#       2 from catboost import CatBoostClassifier, CatBoostRegressor
#       3 from lightgbm import LGBMClassifier, LGBMRegressor
#       4 from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
#
# ImportError: No module named xgboost

# %%
# !pip install xgboost > xgboost.log
# Out:
# Command "python setup.py egg_info" failed with error code 1 in /private/var/folders/_9/tp1qlhsd16ldfxdjgfhzlr3h0000gn/T/pip-build-OtOfJB/xgboost/

# %%
training_data, validation_data = train_test_split(data, random_state=11, train_size=0.1, test_size = 0.1)
X_train = scaler.fit_transform(training_data[features])
print(X_train.shape)
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=5)
clf.fit(X_train, training_data.Label)
# Out:
# (120000, 49)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# Train best model:

# %% [markdown]
# ### Evaluate predictions on the validation sample

# %%
# predict each track
proba = model.predict_proba(X_val)

# %% [markdown]
# ### Log loss on the cross validation sample

# %%
log_loss(validation_data.Label, proba)
# Out:
# 0.69576085141765509

# %% [markdown]
# ## Prepare submission to kaggle

# %%
# predict test sample
X_test = scaler.fit_transform(test[features])
kaggle_proba = clf.predict_proba(X_test)
kaggle_ids = test.ID

# %%
from IPython.display import FileLink

def create_solution(ids, proba, names, filename='baseline.csv'):
    """saves predictions to file and provides a link for downloading """
    solution = pd.DataFrame({'ID': ids})
    
    for name in ['Ghost', 'Electron', 'Muon', 'Pion', 'Kaon', 'Proton']:
        solution[name] = proba[:, np.where(names == name)[0]]
    
    solution.to_csv('{}'.format(filename), index=False)
    return FileLink('{}'.format(filename))
    
create_solution(kaggle_ids, kaggle_proba, clf.classes_)
# Out:
# /Users/Seyed/Documents/ML-Imperial/LHC/baseline.csv
